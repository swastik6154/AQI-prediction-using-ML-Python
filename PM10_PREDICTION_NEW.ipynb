# %% [markdown]
# <a href="https://colab.research.google.com/github/swastik6154/AQI-prediction-using-ML-Python/blob/main/PM10_PREDICTION_NEW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
my_data = pd.read_csv('/content/khandagiri data.csv')

# %%
my_data.head()
# Out:
#          Date   PM10
# 0  04.01.2022  172.0
# 1  06.01.2022  187.0
# 2  10.01.2022  146.0
# 3  12.01.2022  127.0
# 4  18.01.2022  181.0

# %%
my_data.tail()
# Out:
#            Date   PM10
# 423  15.12.2017  125.0
# 424  20.12.2017  107.0
# 425  22.12.2017  104.0
# 426  27.12.2017  114.0
# 427  29.12.2017  103.0

# %%
my_data.isnull().sum()
# Out:
# Date    0
# PM10    0
# dtype: int64

# %%
my_data=my_data.replace(to_replace=-200, value =0)

# %%
my_data.isnull().sum()
# Out:
# Date    0
# PM10    0
# dtype: int64

# %%
my_data.mean()
# Out:
# <ipython-input-23-3ee84403da84>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   my_data.mean()
# PM10    93.729949
# dtype: float64

# %%
my_data=my_data.fillna(my_data.mean)

# %%
my_data.isnull().sum()
# Out:
# Date    0
# PM10    0
# dtype: int64

# %%
date_info=pd.to_datetime(my_data['Date'])
print(date_info)
# Out:
# 0     2022-04-01
# 1     2022-06-01
# 2     2022-10-01
# 3     2022-12-01
# 4     2022-01-18
#          ...
# 423   2017-12-15
# 424   2017-12-20
# 425   2017-12-22
# 426   2017-12-27
# 427   2017-12-29
# Name: Date, Length: 428, dtype: datetime64[ns]
# <ipython-input-57-b212c65ff900>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   date_info=pd.to_datetime(my_data['Date'])

# %%
date_info.head()
# Out:
# 0   2022-04-01
# 1   2022-06-01
# 2   2022-10-01
# 3   2022-12-01
# 4   2022-01-18
# Name: Date, dtype: datetime64[ns]

# %%
date_time = pd.concat([date_info],axis=1)

# %%
date_time.head()
# Out:
#         Date
# 0 2022-04-01
# 1 2022-06-01
# 2 2022-10-01
# 3 2022-12-01
# 4 2022-01-18

# %%
date_time['ds']= date_time['Date'].astype(str)

# %%
date_time.head()
# Out:
#         Date          ds
# 0 2022-04-01  2022-04-01
# 1 2022-06-01  2022-06-01
# 2 2022-10-01  2022-10-01
# 3 2022-12-01  2022-12-01
# 4 2022-01-18  2022-01-18

# %%
date_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    428 non-null    datetime64[ns]
#  1   ds      428 non-null    object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 6.8+ KB

# %%
data=pd.DataFrame()

# %%
data['ds']=pd.to_datetime(date_time['ds'])

# %%
data.head()
# Out:
#           ds
# 0 2022-04-01
# 1 2022-06-01
# 2 2022-10-01
# 3 2022-12-01
# 4 2022-01-18

# %%
data['y']=my_data['PM10']

# %%
data.head()
# Out:
#           ds      y
# 0 2022-04-01  172.0
# 1 2022-06-01  187.0
# 2 2022-10-01  146.0
# 3 2022-12-01  127.0
# 4 2022-01-18  181.0

# %%
from prophet import Prophet
